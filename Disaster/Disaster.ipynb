# %%
import pandas as pd
import numpy as np

# %%
# Import database
dataset = pd.read_csv("D:\Disaster\stormdata_2013.csv")

# %%
dataset.info(verbose = True, null_counts = False)
dataset.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51932 entries, 0 to 51931
# Data columns (total 58 columns):
# BEGIN_YEARMONTH       int64
# BEGIN_DAY             int64
# BEGIN_TIME            int64
# END_YEARMONTH         int64
# END_DAY               int64
# END_TIME              int64
# EPISODE_ID            int64
# EVENT_ID              int64
# STATE                 object
# STATE_FIPS            int64
# YEAR                  int64
# MONTH_NAME            object
# EVENT_TYPE            object
# CZ_TYPE               object
# CZ_FIPS               int64
# CZ_NAME               object
# WFO                   object
# BEGIN_DATE_TIME       object
# CZ_TIMEZONE           object
# END_DATE_TIME         object
# INJURIES_DIRECT       int64
# INJURIES_INDIRECT     int64
# DEATHS_DIRECT         int64
# DEATHS_INDIRECT       int64
# DAMAGE_PROPERTY       object
# DAMAGE_CROPS          object
# SOURCE                object
# MAGNITUDE             float64
# MAGNITUDE_TYPE        object
# ...

# %% [markdown]
# Feature Engineering
# 1. Null Values
#     - Numeric
#     - String
#     -
# 2.

# %% [markdown]
# Split into trainset and dataset

# %%
trainset = dataset.iloc[:(round(len(dataset)*0.80)), :]

# %%
trainset.info(verbose = True, null_counts = False)
trainset.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41546 entries, 0 to 41545
# Data columns (total 58 columns):
# BEGIN_YEARMONTH       int64
# BEGIN_DAY             int64
# BEGIN_TIME            int64
# END_YEARMONTH         int64
# END_DAY               int64
# END_TIME              int64
# EPISODE_ID            int64
# EVENT_ID              int64
# STATE                 object
# STATE_FIPS            int64
# YEAR                  int64
# MONTH_NAME            object
# EVENT_TYPE            object
# CZ_TYPE               object
# CZ_FIPS               int64
# CZ_NAME               object
# WFO                   object
# BEGIN_DATE_TIME       object
# CZ_TIMEZONE           object
# END_DATE_TIME         object
# INJURIES_DIRECT       int64
# INJURIES_INDIRECT     int64
# DEATHS_DIRECT         int64
# DEATHS_INDIRECT       int64
# DAMAGE_PROPERTY       object
# DAMAGE_CROPS          object
# SOURCE                object
# MAGNITUDE             float64
# MAGNITUDE_TYPE        object
# ...

# %%
trainset.head(20)
# Out:
#     BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0            201301          1           0         201301       31      2359
# 1            201301          1           0         201301       31      2359
# 2            201301          1        1230         201301        1      1230
# 3            201301          1        1800         201301        2      1400
# 4            201301          1        1800         201301        2      1400
# 5            201301          1           0         201301       31      2359
# 6            201301          1           0         201301       31      2359
# 7            201301          1           0         201301       31      2359
# 8            201301          1           0         201301       31      2359
# 9            201301          1           0         201301       31      2359
# 10           201301          1           0         201301       31      2359
# ...

# %%
testset = dataset.iloc[(round(len(dataset)*0.80)):, :]

# %%
testset.info(verbose = True, null_counts = False)
testset.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10386 entries, 41546 to 51931
# Data columns (total 58 columns):
# BEGIN_YEARMONTH       int64
# BEGIN_DAY             int64
# BEGIN_TIME            int64
# END_YEARMONTH         int64
# END_DAY               int64
# END_TIME              int64
# EPISODE_ID            int64
# EVENT_ID              int64
# STATE                 object
# STATE_FIPS            int64
# YEAR                  int64
# MONTH_NAME            object
# EVENT_TYPE            object
# CZ_TYPE               object
# CZ_FIPS               int64
# CZ_NAME               object
# WFO                   object
# BEGIN_DATE_TIME       object
# CZ_TIMEZONE           object
# END_DATE_TIME         object
# INJURIES_DIRECT       int64
# INJURIES_INDIRECT     int64
# DEATHS_DIRECT         int64
# DEATHS_INDIRECT       int64
# DAMAGE_PROPERTY       object
# DAMAGE_CROPS          object
# SOURCE                object
# MAGNITUDE             float64
# ...

# %%
testset.head(20)
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 41546           201307         27        1335         201307       27
# 41547           201307         27        1719         201307       27
# 41548           201307         27        1705         201307       27
# 41549           201307         27        1522         201307       27
# 41550           201307         27        2324         201307       27
# 41551           201307         27        1434         201307       27
# 41552           201307         27        1230         201307       27
# 41553           201307         27        1730         201307       27
# 41554           201307         27        1525         201307       27
# 41555           201307         27        2230         201307       27
# 41556           201307         27        2045         201307       27
# 41557           201307         28         132         201307       28
# ...
